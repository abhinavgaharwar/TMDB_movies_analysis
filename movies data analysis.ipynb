# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
movies=pd.read_csv("C:/Users/Abhinav/Documents/data science/term 2/data visualization/tmdb_5000_movies.csv")

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
# 4          http://movies.disney.com/john-carter
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.corr()
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000 -0.089377    0.505414  0.730823  0.269851
# id           -0.089377  1.000000    0.031202 -0.050425 -0.153536
# popularity    0.505414  0.031202    1.000000  0.644724  0.225502
# revenue       0.730823 -0.050425    0.644724  1.000000  0.251093
# runtime       0.269851 -0.153536    0.225502  0.251093  1.000000
# vote_average  0.093146 -0.270595    0.273952  0.197150  0.375046
# vote_count    0.593180 -0.004128    0.778130  0.781487  0.271944
#
#               vote_average  vote_count
# budget            0.093146    0.593180
# id               -0.270595   -0.004128
# popularity        0.273952    0.778130
# revenue           0.197150    0.781487
# runtime           0.375046    0.271944
# vote_average      1.000000    0.312997
# vote_count        0.312997    1.000000

# %%
## correlogram of movies ignoring the id column
movies=movies.drop('id',1)
sns.heatmap(movies.corr(),annot=True,)
plt.show()

# %%
##cluster map of correlation of all numeric column except id columnx=fl.pivot_table(values="passengers",index="month",columns="year")
sns.clustermap(movies.corr())

# %%
##top 10 movies,whose vote_average
##1-between 4-6

# %%
m=movies.query("vote_average=='4'").groupby("popularity").size()
m=pd.DataFrame(m)
m=m.reset_index()
m=m.rename(columns={0:'count'})
m.sort_values(by='count',ascending=False).head(10)
# Out:
#    popularity  count
# 0    0.000372      1
# 1    0.039077      1
# 2    0.218736      1
# 3    0.690089      1
# 4    1.821840      1
# 5    1.859965      1
# 6    2.857848      1
# 7    3.848893      1
# 8    4.822033      1
# 9    5.099472      1

# %%
m=movies[(movies['vote_average']>4 & (movies['vote_average']<6))].sort_values(['popularity'],ascending=[False]).head(10)

# %%
plt.bar(m['original_title'],m['popularity'],color=sns.color_palette("Blues"))
plt.xticks(rotation=90)
plt.show()
